# %%
import pandas as pd
import codecs
import json
from pandas.io.json import json_normalize

# %%
conteudo = open('tweets.json')

# %%
type(conteudo)
# Out:
# _io.TextIOWrapper

# %%
conteudo = open('tweets.json').read()
#_json = json.loads(conteudo)
df = json_normalize(_json)
df = pd.DataFrame.from_dict(_json)

# %%
df.head()
# Out:
#                                            created_at                   id  \
# contributors_enabled   Tue Jul 23 07:00:03 +0000 2019  1153560388123971584
# created_at             Tue Jul 23 07:00:03 +0000 2019  1153560388123971584
# default_profile        Tue Jul 23 07:00:03 +0000 2019  1153560388123971584
# default_profile_image  Tue Jul 23 07:00:03 +0000 2019  1153560388123971584
# description            Tue Jul 23 07:00:03 +0000 2019  1153560388123971584
#
#                                     id_str  \
# contributors_enabled   1153560388123971584
# created_at             1153560388123971584
# default_profile        1153560388123971584
# default_profile_image  1153560388123971584
# description            1153560388123971584
#
#                                                                     text  \
# contributors_enabled   Escala e Rastreamento\nO The Wall Street Journ...
# created_at             Escala e Rastreamento\nO The Wall Street Journ...
# ...

# %%
df2 = pd.read_csv('Tweets_Mg.csv')

# %%
df2.head()
# Out:
#    Unnamed: 0                      Created At  \
# 0           0  Sun Jan 08 01:22:05 +0000 2017
# 1           1  Sun Jan 08 01:49:01 +0000 2017
# 2           2  Sun Jan 08 01:01:46 +0000 2017
# 3           3  Wed Jan 04 21:43:51 +0000 2017
# 4           4  Mon Jan 09 15:08:21 +0000 2017
#
#                                                 Text  \
# 0  ���⛪ @ Catedral de Santo Antônio - Governador ...
# 1  � @ Governador Valadares, Minas Gerais https:/...
# 2  �� @ Governador Valadares, Minas Gerais https:...
# 3                        ��� https://t.co/BnDsO34qK0
# 4  ��� PSOL vai questionar aumento de vereadores ...
#
#    Geo Coordinates.latitude  Geo Coordinates.longitude User Location  \
# 0                       NaN                        NaN        Brasil
# 1                  -41.9333                     -18.85           NaN
# 2                  -41.9333                     -18.85           NaN
# 3                       NaN                        NaN           NaN
# ...

# %%
df2 = df2.drop('Retweet Count',axis=1)

# %%
df2 = df2.drop('Geo Coordinates.latitude',axis=1)
df2 = df2.drop('Geo Coordinates.longitude',axis=1)

# %%
df2 = df2.drop('Observação',axis=1)
for i in range(10,25):
    df2 = df2.drop('Unnamed: {}'.format(i),axis=1)

# %%
df2.head()
# Out:
#    Unnamed: 0                      Created At  \
# 0           0  Sun Jan 08 01:22:05 +0000 2017
# 1           1  Sun Jan 08 01:49:01 +0000 2017
# 2           2  Sun Jan 08 01:01:46 +0000 2017
# 3           3  Wed Jan 04 21:43:51 +0000 2017
# 4           4  Mon Jan 09 15:08:21 +0000 2017
#
#                                                 Text User Location  \
# 0  ���⛪ @ Catedral de Santo Antônio - Governador ...        Brasil
# 1  � @ Governador Valadares, Minas Gerais https:/...           NaN
# 2  �� @ Governador Valadares, Minas Gerais https:...           NaN
# 3                        ��� https://t.co/BnDsO34qK0           NaN
# 4  ��� PSOL vai questionar aumento de vereadores ...           NaN
#
#                Username User Screen Name Classificacao
# 0  Leonardo C Schneider    LeoCSchneider        Neutro
# 1               Wândell         klefnews        Neutro
# 2               Wândell         klefnews        Neutro
# 3         Ana estudando  estudandoconcur        Neutro
# ...

# %%
df2 = df2.drop('Created At',axis=1)
